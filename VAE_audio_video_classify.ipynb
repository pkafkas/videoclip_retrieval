# %%
import os
import numpy as np
import plotly.graph_objs as go
import plotly
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image
from torch.nn import functional as F
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
from scipy.stats import norm
import scipy.io
import os
from math import ceil
import joblib

# %%
# Hyperparameters
batch_size = 128
device = device = ( 'cuda' if torch.cuda.is_available() else 'cpu' )

img_size = 650    # 28x28x1
hidden_dim = 64  # hidden layer dim
#z_dim = 20        # latent space dimension (encoder)
z_dim = 2        # latent space dimension (encoder)

epochs = 10

# %%
# model architecture
class VAE(nn.Module):
  def __init__(self):
    super(VAE, self).__init__()

    # encoder
    self.fc1 = nn.Linear(img_size, hidden_dim)
    self.fc2_mean = nn.Linear(hidden_dim, z_dim)
    self.fc2_logvar = nn.Linear(hidden_dim, z_dim)
    #decoder
    self.fc3 = nn.Linear(z_dim, hidden_dim)
    self.fc4 = nn.Linear(hidden_dim, img_size)

  def encode(self, x):
    h = F.relu(self.fc1(x))
    mu = self.fc2_mean(h)         # compute mean of latent
    logvar = self.fc2_logvar(h)   # compute logvar of latent
    return mu, logvar

  def reparameterize(self, mu, logvar):
    # p(z|x) = mu + std * eps
    std = torch.exp(logvar/2)
    eps = torch.randn_like(std)
    return (mu + eps * std)

  def decode(self, z):
    h = F.relu(self.fc3(z))
    out = torch.sigmoid(self.fc4(h))
    return out

  def forward(self, x):
    # batch_size x 1 x 28 x 28 -> batch_size x 784
    #print(x.view(-1, img_size).shape)
    mu, logvar = self.encode(x.view(-1, img_size))
    z = self.reparameterize(mu, logvar)
    reconstructed = self.decode(z)
    return reconstructed, mu, logvar

# Initialize model, optimizer
model = VAE().to(device)
optim = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
print(model)
# Out:
# VAE(
#   (fc1): Linear(in_features=650, out_features=64, bias=True)
#   (fc2_mean): Linear(in_features=64, out_features=2, bias=True)
#   (fc2_logvar): Linear(in_features=64, out_features=2, bias=True)
#   (fc3): Linear(in_features=2, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=650, bias=True)
# )

# %%
# Define loss function
def loss_function(rec_img, org_img, mu, logvar):
  # Reconstruction loss
  rec_loss = F.binary_cross_entropy(rec_img, org_img.view(-1, img_size), reduction='sum')
  # KL-div loss
  kl_div = 0.5 * torch.sum(logvar.exp() + mu.pow(2) - 1 - logvar)
  #
  return rec_loss + kl_div

# train function
def train(epoch):

  # train function
  model.train()
  train_loss = 0

  for i, (images, _) in enumerate(trainloader):
    images = images.to(device)
    rec_img, mu, logvar = model(images)
    loss = loss_function(rec_img, images, mu, logvar)

    optim.zero_grad()
    loss.backward()
    optim.step()

    train_loss += loss.item()

    if epoch % 400 and epoch > 0:
      #print(f'epoch {epoch}, batch {i}/{len(trainloader)}, loss {loss.item()/len(images)}')
      print(f'----> Epoch {epoch}, Average loss {train_loss/len(trainloader.dataset)}')

  #print(f'----> Epoch {epoch}, Average loss {train_loss/len(trainloader.dataset)}')

# Test function
def test(epoch):
  model.eval()
  test_loss = 0

  with torch.no_grad():
    for i, (images, _) in enumerate(testloader):
      images = images.to(device)
      rec_img, mu, logvar = model(images)
      loss = loss_function(rec_img, images, mu, logvar)
      test_loss += loss.item()

      if i == 0:
        comparison = torch.cat([images[:5], rec_img.view(batch_size, 1, 28, 28)[:5]])
        save_image(comparison.cpu(), f'results/reconstruction_{epoch}.png', nrow=5)

    print(f'----> Average test loss {test_loss/len(testloader.dataset)}')

# %%
model = VAE().to(device)
#model.load_state_dict(torch.load('/content/drive/MyDrive/MultiModalDeepLearning/audio_notebooks/autoenc.pth'))

# %%
fpath = '/content/drive/MyDrive/video_feat/features/audioVideo_features.csv'

df = pd.read_csv(fpath)
#df.tail()

# %%
df2 = df.transpose()
df2.head()

y = list(df.columns)
#print(y)
X = df2.values
#print(X)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(y)
list(le.classes_)
y_new = le.transform(y)

# %%
class MyDataset(Dataset):

  def __init__(self,fpath):
    df = pd.read_csv(fpath)
    df2 = df.transpose()

    X = df2.values
    y = le.transform(list(df.columns))

    self.x_train = torch.tensor(X,dtype=torch.float32)
    self.y_train = torch.tensor(y,dtype=torch.float32)

  def __len__(self):
    return len(self.y_train)

  def __getitem__(self,idx):
    return self.x_train[idx],self.y_train[idx]

# %%
myDs=MyDataset(fpath)
trainloader=  DataLoader(myDs,batch_size=10,shuffle=True)
testloader =  DataLoader(myDs,batch_size=10,shuffle=False)

next(iter(trainloader))
# Out:
# [tensor([[ 0.0382,  0.1334,  3.1703,  ...,  0.4380, -0.0162,  0.0599],
#          [ 0.0150,  0.0793,  3.1717,  ...,  0.6241, -0.0064, -0.0152],
#          [ 0.0463,  0.0900,  3.1739,  ...,  0.3940,  0.0678, -0.1526],
#          ...,
#          [ 0.0728,  0.0374,  3.1686,  ...,  0.7290, -0.1541,  0.0455],
#          [ 0.0518,  0.0554,  3.1475,  ...,  0.5607, -0.1018, -0.0076],
#          [ 0.0319,  0.0713,  3.2474,  ...,  0.4053, -0.0041,  0.0103]]),
#  tensor([66., 29., 17., 60., 23., 69., 70., 46., 37.,  5.])]

# %%
# main function
for epoch in range(1, epochs+1000):
  train(epoch)
  #test(epoch)
# Out:
# Η έξοδος ροής περικόπηκε στις τελευταίες 5000 γραμμές.
# ----> Epoch 453, Average loss -9742.356944444444
# ----> Epoch 453, Average loss -11858.187326388888
# ----> Epoch 453, Average loss -13833.476736111112
# ----> Epoch 453, Average loss -15657.47013888889
# ----> Epoch 453, Average loss -17594.127951388888
# ----> Epoch 454, Average loss -1938.1859375
# ----> Epoch 454, Average loss -4056.7274305555557
# ----> Epoch 454, Average loss -6047.251388888889
# ----> Epoch 454, Average loss -7881.182465277778
# ----> Epoch 454, Average loss -9912.392708333333
# ----> Epoch 454, Average loss -11746.201215277777
# ----> Epoch 454, Average loss -13613.338541666666
# ----> Epoch 454, Average loss -15655.2359375
# ----> Epoch 454, Average loss -17530.024479166666
# ----> Epoch 455, Average loss -1881.7559027777777
# ----> Epoch 455, Average loss -3838.0699652777776
# ----> Epoch 455, Average loss -5635.977083333333
# ----> Epoch 455, Average loss -7698.1046875
# ----> Epoch 455, Average loss -9740.565277777778
# ----> Epoch 455, Average loss -11715.503298611111
# ----> Epoch 455, Average loss -13526.64982638889
# ----> Epoch 455, Average loss -15645.572743055556
# ----> Epoch 455, Average loss -17491.70920138889
# ----> Epoch 456, Average loss -1820.9902777777777
# ----> Epoch 456, Average loss -3816.8786458333334
# ----> Epoch 456, Average loss -5865.305208333333
# ----> Epoch 456, Average loss -7805.5671875
# ----> Epoch 456, Average loss -9630.426909722222
# ----> Epoch 456, Average loss -11552.917881944444
# ----> Epoch 456, Average loss -13751.581944444444
# ----> Epoch 456, Average loss -15696.684375
# ----> Epoch 456, Average loss -17524.355902777777
# ----> Epoch 457, Average loss -1829.3223958333333
# ----> Epoch 457, Average loss -3735.014236111111
# ----> Epoch 457, Average loss -5544.351736111111
# ----> Epoch 457, Average loss -7579.740972222222
# ----> Epoch 457, Average loss -9547.409027777778
# ----> Epoch 457, Average loss -11657.088368055556
# ----> Epoch 457, Average loss -13793.741840277778
# ----> Epoch 457, Average loss -15584.856770833334
# ----> Epoch 457, Average loss -17499.10763888889
# ----> Epoch 458, Average loss -1947.6692708333333
# ----> Epoch 458, Average loss -3951.8298611111113
# ----> Epoch 458, Average loss -5864.334548611111
# ----> Epoch 458, Average loss -7840.386631944444
# ----> Epoch 458, Average loss -9797.71388888889
# ----> Epoch 458, Average loss -11784.669097222222
# ----> Epoch 458, Average loss -13734.892534722223
# ----> Epoch 458, Average loss -15672.216666666667
# ----> Epoch 458, Average loss -17543.6234375
# ----> Epoch 459, Average loss -1849.5102430555555
# ----> Epoch 459, Average loss -3924.5
# ----> Epoch 459, Average loss -5830.467361111111
# ----> Epoch 459, Average loss -7897.8076388888885
# ----> Epoch 459, Average loss -9894.332291666668
# ----> Epoch 459, Average loss -11865.600347222222
# ----> Epoch 459, Average loss -13735.138194444444
# ----> Epoch 459, Average loss -15688.880381944444
# ----> Epoch 459, Average loss -17540.136284722223
# ----> Epoch 460, Average loss -2012.5458333333333
# ----> Epoch 460, Average loss -3945.9527777777776
# ----> Epoch 460, Average loss -5818.884548611111
# ----> Epoch 460, Average loss -7844.277430555556
# ----> Epoch 460, Average loss -9807.61875
# ----> Epoch 460, Average loss -11642.811284722222
# ----> Epoch 460, Average loss -13567.33298611111
# ----> Epoch 460, Average loss -15472.291840277778
# ----> Epoch 460, Average loss -17460.019444444446
# ----> Epoch 461, Average loss -1864.7640625
# ----> Epoch 461, Average loss -3795.984895833333
# ----> Epoch 461, Average loss -5642.2920138888885
# ----> Epoch 461, Average loss -7497.13125
# ----> Epoch 461, Average loss -9679.69045138889
# ----> Epoch 461, Average loss -11562.760590277778
# ----> Epoch 461, Average loss -13558.398090277778
# ----> Epoch 461, Average loss -15556.033506944445
# ----> Epoch 461, Average loss -17499.71736111111
# ----> Epoch 462, Average loss -1813.4366319444443
# ----> Epoch 462, Average loss -3774.1210069444446
# ----> Epoch 462, Average loss -5689.013020833333
# ----> Epoch 462, Average loss -7614.2842013888885
# ----> Epoch 462, Average loss -9751.689756944445
# ----> Epoch 462, Average loss -11809.685590277777
# ----> Epoch 462, Average loss -13572.342534722222
# ----> Epoch 462, Average loss -15484.288020833334
# ----> Epoch 462, Average loss -17566.2296875
# ----> Epoch 463, Average loss -1864.0440972222223
# ----> Epoch 463, Average loss -3991.1637152777776
# ----> Epoch 463, Average loss -5754.186805555555
# ----> Epoch 463, Average loss -7755.161979166666
# ----> Epoch 463, Average loss -9843.866666666667
# ----> Epoch 463, Average loss -11574.673611111111
# ----> Epoch 463, Average loss -13516.10017361111
# ----> Epoch 463, Average loss -15363.108680555555
# ----> Epoch 463, Average loss -17448.676041666666
# ----> Epoch 464, Average loss -1817.5862847222222
# ----> Epoch 464, Average loss -3748.7984375
# ----> Epoch 464, Average loss -5662.280381944444
# ----> Epoch 464, Average loss -7519.645138888889
# ----> Epoch 464, Average loss -9503.852430555555
# ----> Epoch 464, Average loss -11566.652430555556
# ----> Epoch 464, Average loss -13598.857465277777
# ----> Epoch 464, Average loss -15528.439409722223
# ----> Epoch 464, Average loss -17615.808680555554
# ----> Epoch 465, Average loss -1818.765625
# ----> Epoch 465, Average loss -4009.6350694444445
# ----> Epoch 465, Average loss -5902.995659722223
# ----> Epoch 465, Average loss -7931.621701388889
# ----> Epoch 465, Average loss -9678.156770833333
# ----> Epoch 465, Average loss -11683.722569444444
# ----> Epoch 465, Average loss -13621.211805555555
# ----> Epoch 465, Average loss -15452.734722222222
# ----> Epoch 465, Average loss -17489.77847222222
# ----> Epoch 466, Average loss -1953.3493055555555
# ----> Epoch 466, Average loss -3785.554166666667
# ----> Epoch 466, Average loss -5670.279166666666
# ----> Epoch 466, Average loss -7689.3390625
# ----> Epoch 466, Average loss -9471.341145833334
# ----> Epoch 466, Average loss -11325.859375
# ----> Epoch 466, Average loss -13551.277604166668
# ----> Epoch 466, Average loss -15401.303993055555
# ----> Epoch 466, Average loss -17520.90625
# ----> Epoch 467, Average loss -2016.2786458333333
# ----> Epoch 467, Average loss -3922.1927083333335
# ----> Epoch 467, Average loss -5849.740451388889
# ----> Epoch 467, Average loss -7865.421527777778
# ----> Epoch 467, Average loss -9862.64982638889
# ----> Epoch 467, Average loss -11839.938715277778
# ----> Epoch 467, Average loss -13771.722916666668
# ----> Epoch 467, Average loss -15707.49375
# ----> Epoch 467, Average loss -17628.18732638889
# ----> Epoch 468, Average loss -1979.9876736111112
# ----> Epoch 468, Average loss -3942.9505208333335
# ----> Epoch 468, Average loss -5838.440798611111
# ----> Epoch 468, Average loss -7989.190104166667
# ----> Epoch 468, Average loss -9875.866666666667
# ----> Epoch 468, Average loss -11883.615972222222
# ----> Epoch 468, Average loss -13691.855902777777
# ----> Epoch 468, Average loss -15608.96232638889
# ----> Epoch 468, Average loss -17471.41684027778
# ----> Epoch 469, Average loss -2126.4555555555557
# ----> Epoch 469, Average loss -4262.746527777777
# ----> Epoch 469, Average loss -6142.769965277777
# ----> Epoch 469, Average loss -8178.456944444444
# ----> Epoch 469, Average loss -10042.329166666666
# ----> Epoch 469, Average loss -11931.546180555555
# ----> Epoch 469, Average loss -13972.999826388888
# ----> Epoch 469, Average loss -15803.814409722223
# ----> Epoch 469, Average loss -17580.980034722223
# ----> Epoch 470, Average loss -1804.5677083333333
# ----> Epoch 470, Average loss -3786.6267361111113
# ----> Epoch 470, Average loss -5697.124826388889
# ----> Epoch 470, Average loss -7656.874652777778
# ----> Epoch 470, Average loss -9603.969965277778
# ----> Epoch 470, Average loss -11521.996527777777
# ----> Epoch 470, Average loss -13433.423611111111
# ----> Epoch 470, Average loss -15512.158159722223
# ----> Epoch 470, Average loss -17543.259375
# ----> Epoch 471, Average loss -1998.2489583333333
# ----> Epoch 471, Average loss -4000.1119791666665
# ----> Epoch 471, Average loss -5906.094965277778
# ----> Epoch 471, Average loss -7992.579166666666
# ----> Epoch 471, Average loss -9834.501215277778
# ----> Epoch 471, Average loss -11657.690104166666
# ----> Epoch 471, Average loss -13675.609375
# ----> Epoch 471, Average loss -15526.284027777778
# ----> Epoch 471, Average loss -17497.5359375
# ----> Epoch 472, Average loss -1860.4666666666667
# ----> Epoch 472, Average loss -3781.771875
# ----> Epoch 472, Average loss -5850.7265625
# ----> Epoch 472, Average loss -7823.136284722223
# ----> Epoch 472, Average loss -9858.598958333334
# ----> Epoch 472, Average loss -11830.991319444445
# ----> Epoch 472, Average loss -13771.632118055555
# ----> Epoch 472, Average loss -15789.96388888889
# ----> Epoch 472, Average loss -17560.963888888888
# ----> Epoch 473, Average loss -2075.187673611111
# ----> Epoch 473, Average loss -3909.5661458333334
# ----> Epoch 473, Average loss -5857.204513888889
# ----> Epoch 473, Average loss -7910.125
# ----> Epoch 473, Average loss -9774.346875
# ----> Epoch 473, Average loss -11646.3453125
# ----> Epoch 473, Average loss -13422.680034722222
# ----> Epoch 473, Average loss -15579.648958333333
# ----> Epoch 473, Average loss -17526.266493055555
# ----> Epoch 474, Average loss -1944.5482638888889
# ----> Epoch 474, Average loss -3930.9963541666666
# ----> Epoch 474, Average loss -5931.214583333333
# ----> Epoch 474, Average loss -7881.996180555556
# ----> Epoch 474, Average loss -9909.252604166666
# ----> Epoch 474, Average loss -11976.870659722223
# ----> Epoch 474, Average loss -13789.584027777777
# ----> Epoch 474, Average loss -15815.653993055555
# ----> Epoch 474, Average loss -17565.290104166666
# ----> Epoch 475, Average loss -1818.9296875
# ----> Epoch 475, Average loss -3877.620486111111
# ----> Epoch 475, Average loss -5838.953472222222
# ----> Epoch 475, Average loss -7737.763020833333
# ----> Epoch 475, Average loss -9736.296354166667
# ----> Epoch 475, Average loss -11743.868402777778
# ----> Epoch 475, Average loss -13633.013020833334
# ----> Epoch 475, Average loss -15660.86423611111
# ----> Epoch 475, Average loss -17551.764409722222
# ----> Epoch 476, Average loss -1920.7869791666667
# ----> Epoch 476, Average loss -4071.6859375
# ----> Epoch 476, Average loss -6098.283680555555
# ----> Epoch 476, Average loss -8145.932986111111
# ----> Epoch 476, Average loss -10012.751041666666
# ----> Epoch 476, Average loss -11892.833333333334
# ----> Epoch 476, Average loss -13705.351909722222
# ----> Epoch 476, Average loss -15710.618055555555
# ----> Epoch 476, Average loss -17522.866493055557
# ----> Epoch 477, Average loss -2010.1394097222221
# ----> Epoch 477, Average loss -4121.994270833334
# ----> Epoch 477, Average loss -6217.140277777778
# ----> Epoch 477, Average loss -7932.463020833334
# ----> Epoch 477, Average loss -9951.984375
# ----> Epoch 477, Average loss -11729.791493055556
# ----> Epoch 477, Average loss -13785.396875
# ----> Epoch 477, Average loss -15747.068055555555
# ----> Epoch 477, Average loss -17576.300868055554
# ----> Epoch 478, Average loss -1841.9690972222222
# ----> Epoch 478, Average loss -3802.565451388889
# ----> Epoch 478, Average loss -5567.0671875
# ----> Epoch 478, Average loss -7501.528125
# ----> Epoch 478, Average loss -9590.702256944445
# ----> Epoch 478, Average loss -11604.190798611111
# ----> Epoch 478, Average loss -13573.984895833333
# ----> Epoch 478, Average loss -15623.894097222223
# ----> Epoch 478, Average loss -17614.935416666667
# ----> Epoch 479, Average loss -2094.1875
# ----> Epoch 479, Average loss -4247.671527777778
# ----> Epoch 479, Average loss -6032.768402777778
# ----> Epoch 479, Average loss -8002.259548611111
# ----> Epoch 479, Average loss -9949.69375
# ----> Epoch 479, Average loss -11809.322395833333
# ----> Epoch 479, Average loss -13960.190798611111
# ----> Epoch 479, Average loss -15861.77829861111
# ----> Epoch 479, Average loss -17857.18298611111
# ----> Epoch 480, Average loss -1849.4494791666666
# ----> Epoch 480, Average loss -3823.495486111111
# ----> Epoch 480, Average loss -5831.225520833334
# ----> Epoch 480, Average loss -7845.877777777778
# ----> Epoch 480, Average loss -9734.97795138889
# ----> Epoch 480, Average loss -11647.408159722223
# ----> Epoch 480, Average loss -13579.995486111111
# ----> Epoch 480, Average loss -15732.406423611112
# ----> Epoch 480, Average loss -17660.588194444445
# ----> Epoch 481, Average loss -2125.1930555555555
# ----> Epoch 481, Average loss -4014.3723958333335
# ----> Epoch 481, Average loss -5988.13125
# ----> Epoch 481, Average loss -8043.247569444445
# ----> Epoch 481, Average loss -9953.813368055555
# ----> Epoch 481, Average loss -11969.738368055556
# ----> Epoch 481, Average loss -13969.752777777778
# ----> Epoch 481, Average loss -15915.858159722222
# ----> Epoch 481, Average loss -17728.355902777777
# ----> Epoch 482, Average loss -1957.3598958333334
# ----> Epoch 482, Average loss -3962.2625
# ----> Epoch 482, Average loss -5854.715104166667
# ----> Epoch 482, Average loss -7937.4977430555555
# ----> Epoch 482, Average loss -9876.31736111111
# ----> Epoch 482, Average loss -11463.593229166667
# ----> Epoch 482, Average loss -13563.911805555555
# ----> Epoch 482, Average loss -15565.509375
# ----> Epoch 482, Average loss -17546.702256944445
# ----> Epoch 483, Average loss -2191.460416666667
# ----> Epoch 483, Average loss -4316.2236111111115
# ----> Epoch 483, Average loss -6437.603472222222
# ----> Epoch 483, Average loss -8219.814409722223
# ----> Epoch 483, Average loss -10265.500173611112
# ----> Epoch 483, Average loss -12338.7625
# ----> Epoch 483, Average loss -14495.246527777777
# ----> Epoch 483, Average loss -16517.071006944443
# ----> Epoch 483, Average loss -18306.217881944445
# ----> Epoch 484, Average loss -1892.7453125
# ----> Epoch 484, Average loss -3826.933159722222
# ----> Epoch 484, Average loss -5800.359548611111
# ----> Epoch 484, Average loss -7880.2868055555555
# ----> Epoch 484, Average loss -9680.55954861111
# ----> Epoch 484, Average loss -11622.327951388888
# ----> Epoch 484, Average loss -13744.721875
# ----> Epoch 484, Average loss -15968.287847222222
# ----> Epoch 484, Average loss -17760.408333333333
# ----> Epoch 485, Average loss -2164.436111111111
# ----> Epoch 485, Average loss -4107.975694444444
# ----> Epoch 485, Average loss -6176.892534722222
# ----> Epoch 485, Average loss -8071.407291666666
# ----> Epoch 485, Average loss -9964.893923611111
# ----> Epoch 485, Average loss -11839.009895833333
# ----> Epoch 485, Average loss -13981.050868055556
# ----> Epoch 485, Average loss -15850.941840277777
# ----> Epoch 485, Average loss -17770.289583333335
# ----> Epoch 486, Average loss -1894.2871527777777
# ----> Epoch 486, Average loss -3868.8836805555557
# ----> Epoch 486, Average loss -5921.848090277777
# ----> Epoch 486, Average loss -8086.978472222222
# ----> Epoch 486, Average loss -10120.7359375
# ----> Epoch 486, Average loss -12108.543576388889
# ----> Epoch 486, Average loss -13914.6546875
# ----> Epoch 486, Average loss -15712.292361111111
# ----> Epoch 486, Average loss -17667.111805555556
# ----> Epoch 487, Average loss -1872.5598958333333
# ----> Epoch 487, Average loss -3584.206597222222
# ----> Epoch 487, Average loss -5657.922222222222
# ----> Epoch 487, Average loss -7596.812847222222
# ----> Epoch 487, Average loss -9750.333506944444
# ----> Epoch 487, Average loss -11616.76875
# ----> Epoch 487, Average loss -13477.813194444445
# ----> Epoch 487, Average loss -15514.716319444444
# ----> Epoch 487, Average loss -17563.48263888889
# ----> Epoch 488, Average loss -1991.3170138888888
# ----> Epoch 488, Average loss -3824.545833333333
# ----> Epoch 488, Average loss -5726.843576388889
# ----> Epoch 488, Average loss -7670.624652777778
# ----> Epoch 488, Average loss -9785.66875
# ----> Epoch 488, Average loss -11788.002256944445
# ----> Epoch 488, Average loss -13576.889409722222
# ----> Epoch 488, Average loss -15772.899131944445
# ----> Epoch 488, Average loss -17727.639930555557
# ----> Epoch 489, Average loss -2047.5881944444445
# ----> Epoch 489, Average loss -3978.715451388889
# ----> Epoch 489, Average loss -5899.348090277777
# ----> Epoch 489, Average loss -7830.856944444445
# ----> Epoch 489, Average loss -9986.47517361111
# ----> Epoch 489, Average loss -11831.285416666668
# ----> Epoch 489, Average loss -13703.009548611111
# ----> Epoch 489, Average loss -15782.956597222223
# ----> Epoch 489, Average loss -17542.46111111111
# ----> Epoch 490, Average loss -2042.0786458333334
# ----> Epoch 490, Average loss -3903.6036458333333
# ----> Epoch 490, Average loss -5788.237152777778
# ----> Epoch 490, Average loss -7860.7953125
# ----> Epoch 490, Average loss -9846.313541666666
# ----> Epoch 490, Average loss -12044.130034722222
# ----> Epoch 490, Average loss -13918.943576388889
# ----> Epoch 490, Average loss -15779.013194444444
# ----> Epoch 490, Average loss -17561.228645833333
# ----> Epoch 491, Average loss -1929.9621527777779
# ----> Epoch 491, Average loss -4056.5251736111113
# ----> Epoch 491, Average loss -5942.0595486111115
# ----> Epoch 491, Average loss -8015.459027777778
# ----> Epoch 491, Average loss -9683.849305555555
# ----> Epoch 491, Average loss -11581.892534722223
# ----> Epoch 491, Average loss -13454.496701388889
# ----> Epoch 491, Average loss -15676.406597222222
# ----> Epoch 491, Average loss -17590.20763888889
# ----> Epoch 492, Average loss -2023.9053819444443
# ----> Epoch 492, Average loss -4032.6315972222224
# ----> Epoch 492, Average loss -5855.350173611111
# ----> Epoch 492, Average loss -7597.821354166666
# ----> Epoch 492, Average loss -9782.509548611111
# ----> Epoch 492, Average loss -11712.709027777777
# ----> Epoch 492, Average loss -13603.77829861111
# ----> Epoch 492, Average loss -15617.854861111111
# ----> Epoch 492, Average loss -17565.828472222223
# ----> Epoch 493, Average loss -2011.4616319444444
# ----> Epoch 493, Average loss -3860.2673611111113
# ----> Epoch 493, Average loss -5802.916493055555
# ----> Epoch 493, Average loss -7820.1734375
# ----> Epoch 493, Average loss -9702.605902777777
# ----> Epoch 493, Average loss -11706.518402777778
# ----> Epoch 493, Average loss -13490.1265625
# ----> Epoch 493, Average loss -15558.966493055555
# ----> Epoch 493, Average loss -17587.128472222223
# ----> Epoch 494, Average loss -2252.2446180555557
# ----> Epoch 494, Average loss -4291.227083333333
# ----> Epoch 494, Average loss -6269.46875
# ----> Epoch 494, Average loss -8085.0022569444445
# ----> Epoch 494, Average loss -10009.379513888889
# ----> Epoch 494, Average loss -11924.830034722223
# ----> Epoch 494, Average loss -13860.166493055556
# ----> Epoch 494, Average loss -15601.931770833333
# ----> Epoch 494, Average loss -17573.672569444443
# ----> Epoch 495, Average loss -1900.3184027777777
# ----> Epoch 495, Average loss -3650.6237847222224
# ----> Epoch 495, Average loss -5451.155381944444
# ----> Epoch 495, Average loss -7432.903125
# ----> Epoch 495, Average loss -9374.334722222222
# ----> Epoch 495, Average loss -11548.665798611111
# ----> Epoch 495, Average loss -13416.092013888889
# ----> Epoch 495, Average loss -15441.511631944444
# ----> Epoch 495, Average loss -17617.65798611111
# ----> Epoch 496, Average loss -2020.9246527777777
# ----> Epoch 496, Average loss -3995.082986111111
# ----> Epoch 496, Average loss -5834.945138888889
# ----> Epoch 496, Average loss -7721.256423611111
# ----> Epoch 496, Average loss -9638.019270833332
# ----> Epoch 496, Average loss -11569.565798611111
# ----> Epoch 496, Average loss -13407.297569444445
# ----> Epoch 496, Average loss -15319.229340277778
# ----> Epoch 496, Average loss -17548.022569444445
# ----> Epoch 497, Average loss -1853.3694444444445
# ----> Epoch 497, Average loss -3949.7986111111113
# ----> Epoch 497, Average loss -6030.625694444445
# ----> Epoch 497, Average loss -8056.9397569444445
# ----> Epoch 497, Average loss -9943.661284722222
# ----> Epoch 497, Average loss -11954.505034722222
# ----> Epoch 497, Average loss -13700.989930555555
# ----> Epoch 497, Average loss -15779.386284722223
# ----> Epoch 497, Average loss -17576.610069444443
# ----> Epoch 498, Average loss -1850.9413194444444
# ----> Epoch 498, Average loss -3825.925347222222
# ----> Epoch 498, Average loss -5748.3609375
# ----> Epoch 498, Average loss -7797.590625
# ----> Epoch 498, Average loss -9794.424131944445
# ----> Epoch 498, Average loss -11608.255208333334
# ----> Epoch 498, Average loss -13482.819965277778
# ----> Epoch 498, Average loss -15464.905729166667
# ----> Epoch 498, Average loss -17516.027430555554
# ----> Epoch 499, Average loss -2087.7649305555556
# ----> Epoch 499, Average loss -3966.1682291666666
# ----> Epoch 499, Average loss -5931.3180555555555
# ----> Epoch 499, Average loss -7976.643923611111
# ----> Epoch 499, Average loss -9742.646354166667
# ----> Epoch 499, Average loss -11920.752430555556
# ----> Epoch 499, Average loss -13880.898611111112
# ----> Epoch 499, Average loss -16017.777777777777
# ----> Epoch 499, Average loss -17793.57795138889
# ----> Epoch 500, Average loss -2272.9897569444443
# ----> Epoch 500, Average loss -4333.487152777778
# ----> Epoch 500, Average loss -6443.007118055555
# ----> Epoch 500, Average loss -8397.586805555555
# ----> Epoch 500, Average loss -10455.419791666667
# ----> Epoch 500, Average loss -12480.196006944445
# ----> Epoch 500, Average loss -14505.590277777777
# ----> Epoch 500, Average loss -16503.86527777778
# ----> Epoch 500, Average loss -18533.811805555557
# ----> Epoch 501, Average loss -1958.1126736111112
# ----> Epoch 501, Average loss -3823.2809027777776
# ----> Epoch 501, Average loss -5540.0546875
# ----> Epoch 501, Average loss -7864.611284722222
# ----> Epoch 501, Average loss -9707.366840277778
# ----> Epoch 501, Average loss -11692.523263888888
# ----> Epoch 501, Average loss -13768.6515625
# ----> Epoch 501, Average loss -15848.515104166667
# ----> Epoch 501, Average loss -17804.246180555554
# ----> Epoch 502, Average loss -1730.8163194444444
# ----> Epoch 502, Average loss -3725.137152777778
# ----> Epoch 502, Average loss -5724.2555555555555
# ----> Epoch 502, Average loss -7706.228645833334
# ----> Epoch 502, Average loss -9891.8046875
# ----> Epoch 502, Average loss -12085.679861111112
# ----> Epoch 502, Average loss -13985.113715277777
# ----> Epoch 502, Average loss -15963.434201388889
# ----> Epoch 502, Average loss -17833.60625
# ----> Epoch 503, Average loss -1797.806423611111
# ----> Epoch 503, Average loss -3541.8142361111113
# ----> Epoch 503, Average loss -5426.6140625
# ----> Epoch 503, Average loss -7405.358159722222
# ----> Epoch 503, Average loss -9335.075347222222
# ----> Epoch 503, Average loss -11309.5203125
# ----> Epoch 503, Average loss -13480.879513888889
# ----> Epoch 503, Average loss -15531.133854166666
# ----> Epoch 503, Average loss -17683.12482638889
# ----> Epoch 504, Average loss -1985.5534722222221
# ----> Epoch 504, Average loss -3845.473090277778
# ----> Epoch 504, Average loss -5751.860243055556
# ----> Epoch 504, Average loss -7655.663020833334
# ----> Epoch 504, Average loss -9680.29392361111
# ----> Epoch 504, Average loss -11601.453125
# ----> Epoch 504, Average loss -13602.088541666666
# ----> Epoch 504, Average loss -15512.68888888889
# ----> Epoch 504, Average loss -17725.990104166667
# ----> Epoch 505, Average loss -1741.4472222222223
# ----> Epoch 505, Average loss -3782.741666666667
# ----> Epoch 505, Average loss -5667.751041666666
# ----> Epoch 505, Average loss -7453.066145833333
# ----> Epoch 505, Average loss -9461.846180555556
# ----> Epoch 505, Average loss -11475.693576388889
# ----> Epoch 505, Average loss -13554.166145833333
# ----> Epoch 505, Average loss -15593.7671875
# ----> Epoch 505, Average loss -17603.87222222222
# ----> Epoch 506, Average loss -1975.2623263888888
# ----> Epoch 506, Average loss -4144.243229166666
# ----> Epoch 506, Average loss -5998.4125
# ----> Epoch 506, Average loss -7860.073611111111
# ----> Epoch 506, Average loss -9759.059722222222
# ----> Epoch 506, Average loss -11558.080902777778
# ----> Epoch 506, Average loss -13372.522395833334
# ----> Epoch 506, Average loss -15515.530034722222
# ----> Epoch 506, Average loss -17481.434375
# ----> Epoch 507, Average loss -2107.7460069444446
# ----> Epoch 507, Average loss -4033.6090277777776
# ----> Epoch 507, Average loss -6215.189236111111
# ----> Epoch 507, Average loss -8374.893055555556
# ----> Epoch 507, Average loss -10349.896180555555
# ----> Epoch 507, Average loss -12229.81736111111
# ----> Epoch 507, Average loss -14570.3046875
# ----> Epoch 507, Average loss -16807.860243055555
# ----> Epoch 507, Average loss -18894.23888888889
# ----> Epoch 508, Average loss -2184.5364583333335
# ----> Epoch 508, Average loss -4291.9970486111115
# ----> Epoch 508, Average loss -6505.326041666666
# ----> Epoch 508, Average loss -8768.748090277777
# ----> Epoch 508, Average loss -10704.71232638889
# ----> Epoch 508, Average loss -12557.411805555555
# ----> Epoch 508, Average loss -14653.065104166666
# ----> Epoch 508, Average loss -16513.569965277777
# ----> Epoch 508, Average loss -18500.077777777777
# ----> Epoch 509, Average loss -1960.8130208333334
# ----> Epoch 509, Average loss -4007.759722222222
# ----> Epoch 509, Average loss -6043.258854166666
# ----> Epoch 509, Average loss -8169.172569444445
# ----> Epoch 509, Average loss -10069.078819444445
# ----> Epoch 509, Average loss -11980.459027777777
# ----> Epoch 509, Average loss -13811.231944444444
# ----> Epoch 509, Average loss -15781.388020833334
# ----> Epoch 509, Average loss -17781.152430555554
# ----> Epoch 510, Average loss -1885.9159722222223
# ----> Epoch 510, Average loss -4037.2052083333333
# ----> Epoch 510, Average loss -6226.7842013888885
# ----> Epoch 510, Average loss -8084.1696180555555
# ----> Epoch 510, Average loss -9903.620833333332
# ----> Epoch 510, Average loss -12018.2109375
# ----> Epoch 510, Average loss -14189.909375
# ----> Epoch 510, Average loss -15951.968055555555
# ----> Epoch 510, Average loss -17843.44340277778
# ----> Epoch 511, Average loss -1982.8434027777778
# ----> Epoch 511, Average loss -3953.3855902777777
# ----> Epoch 511, Average loss -5960.248611111111
# ----> Epoch 511, Average loss -8101.975347222222
# ----> Epoch 511, Average loss -10227.957638888889
# ----> Epoch 511, Average loss -12387.340972222222
# ----> Epoch 511, Average loss -14215.070833333333
# ----> Epoch 511, Average loss -16039.382465277778
# ----> Epoch 511, Average loss -17752.244618055556
# ----> Epoch 512, Average loss -1828.200173611111
# ----> Epoch 512, Average loss -3780.31875
# ----> Epoch 512, Average loss -5888.386979166667
# ----> Epoch 512, Average loss -7782.3095486111115
# ----> Epoch 512, Average loss -9816.509027777778
# ----> Epoch 512, Average loss -11899.520833333334
# ----> Epoch 512, Average loss -13965.136284722223
# ----> Epoch 512, Average loss -15857.332638888889
# ----> Epoch 512, Average loss -17672.55138888889
# ----> Epoch 513, Average loss -1839.5024305555555
# ----> Epoch 513, Average loss -3654.921701388889
# ----> Epoch 513, Average loss -5623.146006944445
# ----> Epoch 513, Average loss -7561.0890625
# ----> Epoch 513, Average loss -9637.184375
# ----> Epoch 513, Average loss -11679.373263888889
# ----> Epoch 513, Average loss -13634.581597222223
# ----> Epoch 513, Average loss -15473.763368055555
# ----> Epoch 513, Average loss -17636.19375
# ----> Epoch 514, Average loss -2068.2369791666665
# ----> Epoch 514, Average loss -3945.7800347222224
# ----> Epoch 514, Average loss -5995.781076388889
# ----> Epoch 514, Average loss -7883.351388888889
# ----> Epoch 514, Average loss -9585.419965277777
# ----> Epoch 514, Average loss -11695.162152777777
# ----> Epoch 514, Average loss -13783.078298611112
# ----> Epoch 514, Average loss -15683.59670138889
# ----> Epoch 514, Average loss -17621.75607638889
# ----> Epoch 515, Average loss -1992.9739583333333
# ----> Epoch 515, Average loss -3849.1442708333334
# ----> Epoch 515, Average loss -5986.032465277778
# ----> Epoch 515, Average loss -7904.802256944445
# ----> Epoch 515, Average loss -9802.659027777778
# ----> Epoch 515, Average loss -11649.397916666667
# ----> Epoch 515, Average loss -13679.241319444445
# ----> Epoch 515, Average loss -15776.0296875
# ----> Epoch 515, Average loss -17602.833506944444
# ----> Epoch 516, Average loss -1920.0890625
# ----> Epoch 516, Average loss -3871.503298611111
# ----> Epoch 516, Average loss -6074.013715277778
# ----> Epoch 516, Average loss -7873.639409722222
# ----> Epoch 516, Average loss -9735.748090277777
# ----> Epoch 516, Average loss -11828.3
# ----> Epoch 516, Average loss -13696.000868055555
# ----> Epoch 516, Average loss -15683.445833333333
# ----> Epoch 516, Average loss -17612.50590277778
# ----> Epoch 517, Average loss -2018.034201388889
# ----> Epoch 517, Average loss -3848.436458333333
# ----> Epoch 517, Average loss -5961.422743055556
# ----> Epoch 517, Average loss -7877.4140625
# ----> Epoch 517, Average loss -9892.945486111112
# ----> Epoch 517, Average loss -11934.08125
# ----> Epoch 517, Average loss -13864.883333333333
# ----> Epoch 517, Average loss -15774.744791666666
# ----> Epoch 517, Average loss -17606.472395833334
# ----> Epoch 518, Average loss -2138.1432291666665
# ----> Epoch 518, Average loss -4045.3359375
# ----> Epoch 518, Average loss -5997.038715277778
# ----> Epoch 518, Average loss -7825.318402777778
# ----> Epoch 518, Average loss -9940.6828125
# ----> Epoch 518, Average loss -11992.016493055555
# ----> Epoch 518, Average loss -13927.639583333334
# ----> Epoch 518, Average loss -15803.52638888889
# ----> Epoch 518, Average loss -17712.618402777778
# ----> Epoch 519, Average loss -1940.7888888888888
# ----> Epoch 519, Average loss -3805.3473958333334
# ----> Epoch 519, Average loss -5729.604166666667
# ----> Epoch 519, Average loss -7565.463541666667
# ----> Epoch 519, Average loss -9639.568402777777
# ----> Epoch 519, Average loss -11681.164756944445
# ----> Epoch 519, Average loss -13769.336631944445
# ----> Epoch 519, Average loss -15680.220659722223
# ----> Epoch 519, Average loss -17674.36527777778
# ----> Epoch 520, Average loss -2096.9944444444445
# ----> Epoch 520, Average loss -4132.858854166667
# ----> Epoch 520, Average loss -6176.250694444445
# ----> Epoch 520, Average loss -8137.827256944444
# ----> Epoch 520, Average loss -9980.254513888889
# ----> Epoch 520, Average loss -11915.458854166667
# ----> Epoch 520, Average loss -13662.147916666667
# ----> Epoch 520, Average loss -15930.740972222222
# ----> Epoch 520, Average loss -17638.8375
# ----> Epoch 521, Average loss -1814.7289930555555
# ----> Epoch 521, Average loss -3582.3107638888887
# ----> Epoch 521, Average loss -5517.717881944444
# ----> Epoch 521, Average loss -7401.288020833334
# ----> Epoch 521, Average loss -9387.993229166666
# ----> Epoch 521, Average loss -11379.104861111111
# ----> Epoch 521, Average loss -13637.102604166666
# ----> Epoch 521, Average loss -15551.923611111111
# ----> Epoch 521, Average loss -17612.3390625
# ----> Epoch 522, Average loss -2118.154861111111
# ----> Epoch 522, Average loss -3999.2927083333334
# ----> Epoch 522, Average loss -5811.412152777778
# ----> Epoch 522, Average loss -7794.828298611111
# ----> Epoch 522, Average loss -9582.486979166666
# ----> Epoch 522, Average loss -11317.623263888889
# ----> Epoch 522, Average loss -13433.51423611111
# ----> Epoch 522, Average loss -15485.622395833334
# ----> Epoch 522, Average loss -17618.9078125
# ----> Epoch 523, Average loss -1819.2902777777779
# ----> Epoch 523, Average loss -3749.48125
# ----> Epoch 523, Average loss -5707.066666666667
# ----> Epoch 523, Average loss -7477.3265625
# ----> Epoch 523, Average loss -9513.002256944445
# ----> Epoch 523, Average loss -11475.42829861111
# ----> Epoch 523, Average loss -13608.424131944445
# ----> Epoch 523, Average loss -15722.830208333333
# ----> Epoch 523, Average loss -17658.661979166667
# ----> Epoch 524, Average loss -1841.0970486111112
# ----> Epoch 524, Average loss -3835.809548611111
# ----> Epoch 524, Average loss -5862.7868055555555
# ----> Epoch 524, Average loss -7930.621527777777
# ----> Epoch 524, Average loss -9945.24861111111
# ----> Epoch 524, Average loss -11962.525
# ----> Epoch 524, Average loss -13834.580555555556
# ----> Epoch 524, Average loss -15717.158680555556
# ----> Epoch 524, Average loss -17710.032118055555
# ----> Epoch 525, Average loss -1882.9321180555555
# ----> Epoch 525, Average loss -3829.8508680555556
# ----> Epoch 525, Average loss -5692.230381944444
# ----> Epoch 525, Average loss -7822.0517361111115
# ----> Epoch 525, Average loss -9858.43888888889
# ----> Epoch 525, Average loss -11537.60295138889
# ----> Epoch 525, Average loss -13757.492361111112
# ----> Epoch 525, Average loss -15572.408506944445
# ----> Epoch 525, Average loss -17628.763020833332
# ----> Epoch 526, Average loss -1846.9338541666666
# ----> Epoch 526, Average loss -3857.1414930555557
# ----> Epoch 526, Average loss -5835.815277777778
# ----> Epoch 526, Average loss -7881.795659722222
# ----> Epoch 526, Average loss -10005.655902777778
# ----> Epoch 526, Average loss -11860.440972222223
# ----> Epoch 526, Average loss -13903.345833333333
# ----> Epoch 526, Average loss -15911.640277777778
# ----> Epoch 526, Average loss -17610.28923611111
# ----> Epoch 527, Average loss -2022.271875
# ----> Epoch 527, Average loss -4021.776909722222
# ----> Epoch 527, Average loss -5993.217881944444
# ----> Epoch 527, Average loss -8081.455555555555
# ----> Epoch 527, Average loss -9798.764756944445
# ----> Epoch 527, Average loss -12077.50642361111
# ----> Epoch 527, Average loss -13952.686458333334
# ----> Epoch 527, Average loss -15688.226736111112
# ----> Epoch 527, Average loss -17659.411111111112
# ----> Epoch 528, Average loss -1740.8585069444443
# ----> Epoch 528, Average loss -3907.959027777778
# ----> Epoch 528, Average loss -5680.488541666667
# ----> Epoch 528, Average loss -7760.283159722222
# ----> Epoch 528, Average loss -9750.580729166666
# ----> Epoch 528, Average loss -11624.692534722222
# ----> Epoch 528, Average loss -13647.981944444444
# ----> Epoch 528, Average loss -15579.015798611112
# ----> Epoch 528, Average loss -17633.996006944446
# ----> Epoch 529, Average loss -1994.1168402777778
# ----> Epoch 529, Average loss -3653.298263888889
# ----> Epoch 529, Average loss -5760.503993055556
# ----> Epoch 529, Average loss -8036.651909722223
# ----> Epoch 529, Average loss -9864.230208333332
# ----> Epoch 529, Average loss -12149.679166666667
# ----> Epoch 529, Average loss -14259.517534722223
# ----> Epoch 529, Average loss -16176.506944444445
# ----> Epoch 529, Average loss -18423.860590277778
# ----> Epoch 530, Average loss -2268.9909722222224
# ----> Epoch 530, Average loss -4416.940277777778
# ----> Epoch 530, Average loss -6658.3953125
# ----> Epoch 530, Average loss -8488.025347222223
# ----> Epoch 530, Average loss -10491.886111111111
# ----> Epoch 530, Average loss -12671.260416666666
# ----> Epoch 530, Average loss -14762.544618055555
# ----> Epoch 530, Average loss -16925.571354166666
# ----> Epoch 530, Average loss -19132.20625
# ----> Epoch 531, Average loss -2220.533159722222
# ----> Epoch 531, Average loss -4466.6171875
# ----> Epoch 531, Average loss -6494.464930555556
# ----> Epoch 531, Average loss -8273.338020833333
# ----> Epoch 531, Average loss -10209.714236111111
# ----> Epoch 531, Average loss -12180.683159722223
# ----> Epoch 531, Average loss -14242.466493055555
# ----> Epoch 531, Average loss -16308.871875
# ----> Epoch 531, Average loss -18243.08611111111
# ----> Epoch 532, Average loss -1925.9944444444445
# ----> Epoch 532, Average loss -3955.4635416666665
# ----> Epoch 532, Average loss -5963.619097222222
# ----> Epoch 532, Average loss -7998.5361111111115
# ----> Epoch 532, Average loss -10132.023958333333
# ----> Epoch 532, Average loss -12110.690277777778
# ----> Epoch 532, Average loss -14016.01701388889
# ----> Epoch 532, Average loss -15958.736631944445
# ----> Epoch 532, Average loss -17861.680034722223
# ----> Epoch 533, Average loss -2061.446354166667
# ----> Epoch 533, Average loss -4050.3272569444443
# ----> Epoch 533, Average loss -6327.502604166667
# ----> Epoch 533, Average loss -8370.973958333334
# ----> Epoch 533, Average loss -10352.038888888888
# ----> Epoch 533, Average loss -12199.08298611111
# ----> Epoch 533, Average loss -14254.969618055555
# ----> Epoch 533, Average loss -16179.765972222222
# ----> Epoch 533, Average loss -17909.011284722223
# ----> Epoch 534, Average loss -1880.0762152777777
# ----> Epoch 534, Average loss -3736.272395833333
# ----> Epoch 534, Average loss -5739.146701388889
# ----> Epoch 534, Average loss -7678.6227430555555
# ----> Epoch 534, Average loss -9596.266666666666
# ----> Epoch 534, Average loss -11620.222743055556
# ----> Epoch 534, Average loss -13750.703645833333
# ----> Epoch 534, Average loss -15717.57326388889
# ----> Epoch 534, Average loss -17736.19027777778
# ----> Epoch 535, Average loss -1882.6961805555557
# ----> Epoch 535, Average loss -3775.4939236111113
# ----> Epoch 535, Average loss -5795.841319444445
# ----> Epoch 535, Average loss -7824.088368055555
# ----> Epoch 535, Average loss -9773.632291666667
# ----> Epoch 535, Average loss -11634.244965277778
# ----> Epoch 535, Average loss -13714.034895833332
# ----> Epoch 535, Average loss -15790.513368055555
# ----> Epoch 535, Average loss -17707.92361111111
# ----> Epoch 536, Average loss -1975.9618055555557
# ----> Epoch 536, Average loss -3893.3987847222224
# ----> Epoch 536, Average loss -5829.539409722222
# ----> Epoch 536, Average loss -7787.219444444445
# ----> Epoch 536, Average loss -9671.7203125
# ----> Epoch 536, Average loss -11645.466493055555
# ----> Epoch 536, Average loss -13698.837847222223
# ----> Epoch 536, Average loss -15795.782118055555
# ----> Epoch 536, Average loss -17742.7671875
# ----> Epoch 537, Average loss -2016.353298611111
# ----> Epoch 537, Average loss -4229.980034722223
# ----> Epoch 537, Average loss -5981.186284722222
# ----> Epoch 537, Average loss -7925.141666666666
# ----> Epoch 537, Average loss -9930.663194444445
# ----> Epoch 537, Average loss -11847.7640625
# ----> Epoch 537, Average loss -13796.496006944444
# ----> Epoch 537, Average loss -15653.166319444445
# ----> Epoch 537, Average loss -17685.445659722223
# ----> Epoch 538, Average loss -2020.1925347222223
# ----> Epoch 538, Average loss -4217.324131944444
# ----> Epoch 538, Average loss -6121.751215277778
# ----> Epoch 538, Average loss -8201.581944444444
# ----> Epoch 538, Average loss -10216.177256944444
# ----> Epoch 538, Average loss -12020.192708333334
# ----> Epoch 538, Average loss -13973.159027777778
# ----> Epoch 538, Average loss -15942.995833333332
# ----> Epoch 538, Average loss -17778.188368055555
# ----> Epoch 539, Average loss -1924.6380208333333
# ----> Epoch 539, Average loss -3818.0171875
# ----> Epoch 539, Average loss -5768.620659722223
# ----> Epoch 539, Average loss -7715.029861111111
# ----> Epoch 539, Average loss -9566.179861111112
# ----> Epoch 539, Average loss -11563.300520833332
# ----> Epoch 539, Average loss -13698.147222222222
# ----> Epoch 539, Average loss -15600.785590277777
# ----> Epoch 539, Average loss -17664.622569444444
# ----> Epoch 540, Average loss -2018.0081597222222
# ----> Epoch 540, Average loss -3932.3131944444444
# ----> Epoch 540, Average loss -5942.194965277778
# ----> Epoch 540, Average loss -7967.606770833333
# ----> Epoch 540, Average loss -9891.14548611111
# ----> Epoch 540, Average loss -12084.824305555556
# ----> Epoch 540, Average loss -14074.863368055556
# ----> Epoch 540, Average loss -16247.674305555556
# ----> Epoch 540, Average loss -18125.883506944443
# ----> Epoch 541, Average loss -1950.0532986111111
# ----> Epoch 541, Average loss -4096.5671875
# ----> Epoch 541, Average loss -6058.765451388889
# ----> Epoch 541, Average loss -7907.440972222223
# ----> Epoch 541, Average loss -9891.17482638889
# ----> Epoch 541, Average loss -11833.652777777777
# ----> Epoch 541, Average loss -13802.200347222222
# ----> Epoch 541, Average loss -15872.627256944445
# ----> Epoch 541, Average loss -17856.797569444443
# ----> Epoch 542, Average loss -2045.2039930555557
# ----> Epoch 542, Average loss -3924.352083333333
# ----> Epoch 542, Average loss -5581.874131944444
# ----> Epoch 542, Average loss -7515.839409722223
# ----> Epoch 542, Average loss -9609.45
# ----> Epoch 542, Average loss -11782.234027777778
# ----> Epoch 542, Average loss -13929.780381944445
# ----> Epoch 542, Average loss -15889.5125
# ----> Epoch 542, Average loss -17837.10486111111
# ----> Epoch 543, Average loss -2023.5144097222221
# ----> Epoch 543, Average loss -4075.3097222222223
# ----> Epoch 543, Average loss -6234.277256944444
# ----> Epoch 543, Average loss -8051.040104166666
# ----> Epoch 543, Average loss -9961.092534722222
# ----> Epoch 543, Average loss -11919.381770833334
# ----> Epoch 543, Average loss -13958.460416666667
# ----> Epoch 543, Average loss -16033.802604166667
# ----> Epoch 543, Average loss -17833.793923611112
# ----> Epoch 544, Average loss -2136.1118055555557
# ----> Epoch 544, Average loss -3949.1192708333333
# ----> Epoch 544, Average loss -5985.311458333334
# ----> Epoch 544, Average loss -7933.852430555556
# ----> Epoch 544, Average loss -9909.842013888889
# ----> Epoch 544, Average loss -11930.288715277778
# ----> Epoch 544, Average loss -13974.489756944444
# ----> Epoch 544, Average loss -15864.445486111112
# ----> Epoch 544, Average loss -17804.344097222223
# ----> Epoch 545, Average loss -1959.032986111111
# ----> Epoch 545, Average loss -3852.6628472222224
# ----> Epoch 545, Average loss -5908.696180555556
# ----> Epoch 545, Average loss -8030.100173611111
# ----> Epoch 545, Average loss -9896.809201388889
# ----> Epoch 545, Average loss -11634.555902777778
# ----> Epoch 545, Average loss -13513.027604166668
# ----> Epoch 545, Average loss -15503.860416666666
# ----> Epoch 545, Average loss -17707.736805555556
# ----> Epoch 546, Average loss -1935.5880208333333
# ----> Epoch 546, Average loss -4044.191840277778
# ----> Epoch 546, Average loss -6036.753993055556
# ----> Epoch 546, Average loss -8046.550694444444
# ----> Epoch 546, Average loss -10118.13142361111
# ----> Epoch 546, Average loss -11942.092013888889
# ----> Epoch 546, Average loss -13724.426215277777
# ----> Epoch 546, Average loss -15737.067013888889
# ----> Epoch 546, Average loss -17651.98715277778
# ----> Epoch 547, Average loss -2063.4494791666666
# ----> Epoch 547, Average loss -3998.3260416666667
# ----> Epoch 547, Average loss -6072.248784722222
# ----> Epoch 547, Average loss -8109.250347222222
# ----> Epoch 547, Average loss -9947.809375
# ----> Epoch 547, Average loss -12116.98923611111
# ----> Epoch 547, Average loss -13899.736631944445
# ----> Epoch 547, Average loss -15740.156944444445
# ----> Epoch 547, Average loss -17754.04861111111
# ----> Epoch 548, Average loss -2113.915625
# ----> Epoch 548, Average loss -4197.461631944445
# ----> Epoch 548, Average loss -5852.646875
# ----> Epoch 548, Average loss -7797.104340277778
# ----> Epoch 548, Average loss -9731.234722222222
# ----> Epoch 548, Average loss -11692.007986111112
# ----> Epoch 548, Average loss -13822.30763888889
# ----> Epoch 548, Average loss -15595.744097222223
# ----> Epoch 548, Average loss -17605.543055555554
# ----> Epoch 549, Average loss -1974.54375
# ----> Epoch 549, Average loss -3833.897395833333
# ----> Epoch 549, Average loss -5862.490277777778
# ----> Epoch 549, Average loss -7849.563020833333
# ----> Epoch 549, Average loss -9780.268923611111
# ----> Epoch 549, Average loss -11793.174131944445
# ----> Epoch 549, Average loss -13654.671180555555
# ----> Epoch 549, Average loss -15955.759548611111
# ----> Epoch 549, Average loss -17709.722916666666
# ----> Epoch 550, Average loss -1908.862326388889
# ----> Epoch 550, Average loss -3901.1875
# ----> Epoch 550, Average loss -5926.927777777778
# ----> Epoch 550, Average loss -7755.765277777778
# ----> Epoch 550, Average loss -9893.91875
# ----> Epoch 550, Average loss -11996.655729166667
# ----> Epoch 550, Average loss -13648.346875
# ----> Epoch 550, Average loss -15738.803472222222
# ----> Epoch 550, Average loss -17676.125520833335
# ----> Epoch 551, Average loss -2051.3552083333334
# ----> Epoch 551, Average loss -4025.8909722222224
# ----> Epoch 551, Average loss -5958.770833333333
# ----> Epoch 551, Average loss -8079.098090277777
# ----> Epoch 551, Average loss -9992.440277777778
# ----> Epoch 551, Average loss -11858.203298611112
# ----> Epoch 551, Average loss -13789.804861111112
# ----> Epoch 551, Average loss -15703.77204861111
# ----> Epoch 551, Average loss -17716.502951388888
# ----> Epoch 552, Average loss -1930.3046875
# ----> Epoch 552, Average loss -3853.359201388889
# ----> Epoch 552, Average loss -5746.040625
# ----> Epoch 552, Average loss -7939.109201388889
# ----> Epoch 552, Average loss -9858.073611111111
# ----> Epoch 552, Average loss -11943.656076388888
# ----> Epoch 552, Average loss -13848.479861111111
# ----> Epoch 552, Average loss -15639.591840277777
# ----> Epoch 552, Average loss -17719.95
# ----> Epoch 553, Average loss -2061.8555555555554
# ----> Epoch 553, Average loss -3976.8565972222223
# ----> Epoch 553, Average loss -5852.352604166666
# ----> Epoch 553, Average loss -7879.343229166667
# ----> Epoch 553, Average loss -9899.579340277778
# ----> Epoch 553, Average loss -11841.491666666667
# ----> Epoch 553, Average loss -13725.052777777777
# ----> Epoch 553, Average loss -15748.4640625
# ----> Epoch 553, Average loss -17759.561805555557
# ----> Epoch 554, Average loss -2078.336111111111
# ----> Epoch 554, Average loss -3891.834027777778
# ----> Epoch 554, Average loss -5726.038368055555
# ----> Epoch 554, Average loss -7722.425
# ----> Epoch 554, Average loss -9874.6234375
# ----> Epoch 554, Average loss -11751.248263888889
# ----> Epoch 554, Average loss -13934.427777777777
# ----> Epoch 554, Average loss -15700.316840277777
# ----> Epoch 554, Average loss -17647.780208333334
# ----> Epoch 555, Average loss -2100.503125
# ----> Epoch 555, Average loss -4033.849652777778
# ----> Epoch 555, Average loss -5910.214756944444
# ----> Epoch 555, Average loss -7970.436631944444
# ----> Epoch 555, Average loss -9883.028472222222
# ----> Epoch 555, Average loss -11872.226736111112
# ----> Epoch 555, Average loss -13807.22361111111
# ----> Epoch 555, Average loss -15629.188715277778
# ----> Epoch 555, Average loss -17762.371180555554
# ----> Epoch 556, Average loss -2043.7741319444444
# ----> Epoch 556, Average loss -4181.765277777778
# ----> Epoch 556, Average loss -6301.430729166666
# ----> Epoch 556, Average loss -8209.521006944444
# ----> Epoch 556, Average loss -10149.625173611112
# ----> Epoch 556, Average loss -11863.652430555556
# ----> Epoch 556, Average loss -13927.286805555555
# ----> Epoch 556, Average loss -15787.803993055555
# ----> Epoch 556, Average loss -17714.877604166668
# ----> Epoch 557, Average loss -1901.509375
# ----> Epoch 557, Average loss -3961.035590277778
# ----> Epoch 557, Average loss -5861.2109375
# ----> Epoch 557, Average loss -7693.964409722223
# ----> Epoch 557, Average loss -9724.296527777778
# ----> Epoch 557, Average loss -11866.227083333333
# ----> Epoch 557, Average loss -13944.714236111111
# ----> Epoch 557, Average loss -15872.246180555556
# ----> Epoch 557, Average loss -17706.425
# ----> Epoch 558, Average loss -1977.9262152777778
# ----> Epoch 558, Average loss -4207.182986111111
# ----> Epoch 558, Average loss -6152.373611111111
# ----> Epoch 558, Average loss -8223.704340277778
# ----> Epoch 558, Average loss -10134.453472222222
# ----> Epoch 558, Average loss -12077.383854166666
# ----> Epoch 558, Average loss -13945.79982638889
# ----> Epoch 558, Average loss -15968.04826388889
# ----> Epoch 558, Average loss -17735.20138888889
# ----> Epoch 559, Average loss -1905.2527777777777
# ----> Epoch 559, Average loss -3864.988715277778
# ----> Epoch 559, Average loss -5817.4203125
# ----> Epoch 559, Average loss -7679.761111111111
# ----> Epoch 559, Average loss -9610.891145833333
# ----> Epoch 559, Average loss -11629.999305555555
# ----> Epoch 559, Average loss -13595.78125
# ----> Epoch 559, Average loss -15639.727604166666
# ----> Epoch 559, Average loss -17739.799131944445
# ----> Epoch 560, Average loss -1925.2032986111112
# ----> Epoch 560, Average loss -3877.3512152777776
# ----> Epoch 560, Average loss -5989.483159722222
# ----> Epoch 560, Average loss -8043.7008680555555
# ----> Epoch 560, Average loss -10135.261458333332
# ----> Epoch 560, Average loss -12103.361979166666
# ----> Epoch 560, Average loss -13875.20451388889
# ----> Epoch 560, Average loss -15879.927430555555
# ----> Epoch 560, Average loss -17726.111805555556
# ----> Epoch 561, Average loss -2011.045138888889
# ----> Epoch 561, Average loss -4021.234548611111
# ----> Epoch 561, Average loss -5944.176909722222
# ----> Epoch 561, Average loss -7892.1859375
# ----> Epoch 561, Average loss -9724.083333333334
# ----> Epoch 561, Average loss -11739.440798611111
# ----> Epoch 561, Average loss -13883.858159722222
# ----> Epoch 561, Average loss -15813.585416666667
# ----> Epoch 561, Average loss -17730.759895833333
# ----> Epoch 562, Average loss -2026.7578125
# ----> Epoch 562, Average loss -3899.6119791666665
# ----> Epoch 562, Average loss -5998.556597222222
# ----> Epoch 562, Average loss -8018.102604166666
# ...
# ----> Epoch 973, Average loss -18738.08923611111
# ----> Epoch 974, Average loss -1955.628125
# ----> Epoch 974, Average loss -4036.487326388889
# ----> Epoch 974, Average loss -6105.338368055555
# ----> Epoch 974, Average loss -8263.945138888888
# ----> Epoch 974, Average loss -10386.179513888888
# ----> Epoch 974, Average loss -12696.44236111111
# ----> Epoch 974, Average loss -14667.269618055556
# ----> Epoch 974, Average loss -16736.47673611111
# ----> Epoch 974, Average loss -18646.374652777777
# ----> Epoch 975, Average loss -2163.336979166667
# ----> Epoch 975, Average loss -4298.973090277777
# ----> Epoch 975, Average loss -6252.882638888889
# ----> Epoch 975, Average loss -8212.641145833333
# ----> Epoch 975, Average loss -10359.126736111111
# ----> Epoch 975, Average loss -12373.748090277777
# ----> Epoch 975, Average loss -14733.16267361111
# ----> Epoch 975, Average loss -16952.573958333334
# ----> Epoch 975, Average loss -18759.875868055555
# ----> Epoch 976, Average loss -1866.5484375
# ----> Epoch 976, Average loss -4070.75
# ----> Epoch 976, Average loss -5886.362152777778
# ----> Epoch 976, Average loss -8216.875520833333
# ----> Epoch 976, Average loss -10275.480902777777
# ----> Epoch 976, Average loss -12405.972916666668
# ----> Epoch 976, Average loss -14368.325520833334
# ----> Epoch 976, Average loss -16544.77065972222
# ----> Epoch 976, Average loss -18751.575694444444
# ----> Epoch 977, Average loss -1797.6899305555555
# ----> Epoch 977, Average loss -3893.5828125
# ----> Epoch 977, Average loss -5800.473958333333
# ----> Epoch 977, Average loss -7953.914583333333
# ----> Epoch 977, Average loss -10274.057465277778
# ----> Epoch 977, Average loss -12472.101215277778
# ----> Epoch 977, Average loss -14528.5875
# ----> Epoch 977, Average loss -16484.788715277777
# ----> Epoch 977, Average loss -18662.69548611111
# ----> Epoch 978, Average loss -2142.1223958333335
# ----> Epoch 978, Average loss -4181.8460069444445
# ----> Epoch 978, Average loss -6092.687847222222
# ----> Epoch 978, Average loss -8169.130381944445
# ----> Epoch 978, Average loss -9903.86579861111
# ----> Epoch 978, Average loss -11996.782465277778
# ----> Epoch 978, Average loss -14150.55329861111
# ----> Epoch 978, Average loss -16413.463541666668
# ----> Epoch 978, Average loss -18650.483680555557
# ----> Epoch 979, Average loss -1943.2491319444443
# ----> Epoch 979, Average loss -4004.2442708333333
# ----> Epoch 979, Average loss -6091.425868055556
# ----> Epoch 979, Average loss -8327.237673611111
# ----> Epoch 979, Average loss -10268.193576388889
# ----> Epoch 979, Average loss -12190.994965277778
# ----> Epoch 979, Average loss -14431.877256944445
# ----> Epoch 979, Average loss -16604.803819444445
# ----> Epoch 979, Average loss -18720.563541666666
# ----> Epoch 980, Average loss -2269.332638888889
# ----> Epoch 980, Average loss -4137.359375
# ----> Epoch 980, Average loss -6388.667881944444
# ----> Epoch 980, Average loss -8368.676388888889
# ----> Epoch 980, Average loss -10208.2734375
# ----> Epoch 980, Average loss -12316.249826388888
# ----> Epoch 980, Average loss -14516.870486111111
# ----> Epoch 980, Average loss -16651.686979166665
# ----> Epoch 980, Average loss -18722.399652777778
# ----> Epoch 981, Average loss -2189.495659722222
# ----> Epoch 981, Average loss -4189.2053819444445
# ----> Epoch 981, Average loss -6460.731076388889
# ----> Epoch 981, Average loss -8586.457118055556
# ----> Epoch 981, Average loss -10569.816319444444
# ----> Epoch 981, Average loss -12679.988888888889
# ----> Epoch 981, Average loss -14502.71579861111
# ----> Epoch 981, Average loss -16574.935416666667
# ----> Epoch 981, Average loss -18705.45902777778
# ----> Epoch 982, Average loss -2128.894097222222
# ----> Epoch 982, Average loss -4141.5420138888885
# ----> Epoch 982, Average loss -6187.265104166667
# ----> Epoch 982, Average loss -8213.391666666666
# ----> Epoch 982, Average loss -10615.823090277778
# ----> Epoch 982, Average loss -12642.374305555555
# ----> Epoch 982, Average loss -14653.686631944445
# ----> Epoch 982, Average loss -16616.300520833334
# ----> Epoch 982, Average loss -18683.53125
# ----> Epoch 983, Average loss -1968.6041666666667
# ----> Epoch 983, Average loss -3912.748611111111
# ----> Epoch 983, Average loss -6202.765451388889
# ----> Epoch 983, Average loss -8163.7633680555555
# ----> Epoch 983, Average loss -10290.886284722223
# ----> Epoch 983, Average loss -12497.605902777777
# ----> Epoch 983, Average loss -14521.475694444445
# ----> Epoch 983, Average loss -16536.088541666668
# ----> Epoch 983, Average loss -18751.563715277778
# ----> Epoch 984, Average loss -2003.237326388889
# ----> Epoch 984, Average loss -4038.5256944444445
# ----> Epoch 984, Average loss -6101.6689236111115
# ----> Epoch 984, Average loss -8405.571006944445
# ----> Epoch 984, Average loss -10214.905381944445
# ----> Epoch 984, Average loss -12508.890277777778
# ----> Epoch 984, Average loss -14641.871006944444
# ----> Epoch 984, Average loss -16732.444270833334
# ----> Epoch 984, Average loss -18755.49236111111
# ----> Epoch 985, Average loss -2256.0720486111113
# ----> Epoch 985, Average loss -4183.025868055555
# ----> Epoch 985, Average loss -6111.352083333333
# ----> Epoch 985, Average loss -8144.357465277778
# ----> Epoch 985, Average loss -10219.383506944445
# ----> Epoch 985, Average loss -12296.016840277778
# ----> Epoch 985, Average loss -14349.111111111111
# ----> Epoch 985, Average loss -16635.520833333332
# ----> Epoch 985, Average loss -18727.09704861111
# ----> Epoch 986, Average loss -2256.945486111111
# ----> Epoch 986, Average loss -4305.634548611111
# ----> Epoch 986, Average loss -6365.9814236111115
# ----> Epoch 986, Average loss -8590.599479166667
# ----> Epoch 986, Average loss -10569.443055555555
# ----> Epoch 986, Average loss -12602.446875
# ----> Epoch 986, Average loss -14751.594618055555
# ----> Epoch 986, Average loss -16701.394097222223
# ----> Epoch 986, Average loss -18750.64826388889
# ----> Epoch 987, Average loss -2021.7958333333333
# ----> Epoch 987, Average loss -4130.742534722222
# ----> Epoch 987, Average loss -6103.053472222222
# ----> Epoch 987, Average loss -8104.027604166667
# ----> Epoch 987, Average loss -10125.05625
# ----> Epoch 987, Average loss -12361.128298611111
# ----> Epoch 987, Average loss -14618.988541666668
# ----> Epoch 987, Average loss -16726.10746527778
# ----> Epoch 987, Average loss -18710.902083333334
# ----> Epoch 988, Average loss -1945.373263888889
# ----> Epoch 988, Average loss -4273.324826388889
# ----> Epoch 988, Average loss -6363.201388888889
# ----> Epoch 988, Average loss -8417.075868055555
# ----> Epoch 988, Average loss -10597.94045138889
# ----> Epoch 988, Average loss -12414.885069444445
# ----> Epoch 988, Average loss -14428.661979166667
# ----> Epoch 988, Average loss -16583.913541666665
# ----> Epoch 988, Average loss -18761.333680555555
# ----> Epoch 989, Average loss -1980.5991319444445
# ----> Epoch 989, Average loss -4258.438888888889
# ----> Epoch 989, Average loss -6255.890625
# ----> Epoch 989, Average loss -8314.216493055555
# ----> Epoch 989, Average loss -10303.007638888888
# ----> Epoch 989, Average loss -12301.202951388888
# ----> Epoch 989, Average loss -14444.494270833333
# ----> Epoch 989, Average loss -16621.144270833334
# ----> Epoch 989, Average loss -18800.21267361111
# ----> Epoch 990, Average loss -2100.1569444444444
# ----> Epoch 990, Average loss -4163.239583333333
# ----> Epoch 990, Average loss -6268.478645833334
# ----> Epoch 990, Average loss -8395.481597222222
# ----> Epoch 990, Average loss -10283.41267361111
# ----> Epoch 990, Average loss -12202.0078125
# ----> Epoch 990, Average loss -14459.515625
# ----> Epoch 990, Average loss -16776.43420138889
# ----> Epoch 990, Average loss -18944.214930555554
# ----> Epoch 991, Average loss -2058.326215277778
# ----> Epoch 991, Average loss -4138.661458333333
# ----> Epoch 991, Average loss -6320.837673611111
# ----> Epoch 991, Average loss -8593.344444444445
# ----> Epoch 991, Average loss -10920.7921875
# ----> Epoch 991, Average loss -13063.239583333334
# ----> Epoch 991, Average loss -15174.382118055555
# ----> Epoch 991, Average loss -17024.709375
# ----> Epoch 991, Average loss -19227.40034722222
# ----> Epoch 992, Average loss -2213.8743055555556
# ----> Epoch 992, Average loss -4351.244097222222
# ----> Epoch 992, Average loss -6164.930381944445
# ----> Epoch 992, Average loss -8244.717534722222
# ----> Epoch 992, Average loss -10292.546006944445
# ----> Epoch 992, Average loss -12395.207638888889
# ----> Epoch 992, Average loss -14389.452083333334
# ----> Epoch 992, Average loss -16484.479166666668
# ----> Epoch 992, Average loss -18569.25972222222
# ----> Epoch 993, Average loss -2097.285590277778
# ----> Epoch 993, Average loss -4229.121875
# ----> Epoch 993, Average loss -6150.694097222222
# ----> Epoch 993, Average loss -8411.081423611111
# ----> Epoch 993, Average loss -10617.6265625
# ----> Epoch 993, Average loss -12764.317013888889
# ----> Epoch 993, Average loss -14803.829340277778
# ----> Epoch 993, Average loss -16796.73125
# ----> Epoch 993, Average loss -18910.858854166665
# ----> Epoch 994, Average loss -2148.5359375
# ----> Epoch 994, Average loss -4135.455208333334
# ----> Epoch 994, Average loss -6408.774479166666
# ----> Epoch 994, Average loss -8540.806770833333
# ----> Epoch 994, Average loss -10731.5359375
# ----> Epoch 994, Average loss -12907.778819444444
# ----> Epoch 994, Average loss -14815.489930555555
# ----> Epoch 994, Average loss -16893.164756944443
# ----> Epoch 994, Average loss -18899.241319444445
# ----> Epoch 995, Average loss -1845.6855902777777
# ----> Epoch 995, Average loss -4068.6600694444446
# ----> Epoch 995, Average loss -6211.500173611111
# ----> Epoch 995, Average loss -8375.44236111111
# ----> Epoch 995, Average loss -10263.040277777778
# ----> Epoch 995, Average loss -12491.919965277777
# ----> Epoch 995, Average loss -14566.73732638889
# ----> Epoch 995, Average loss -16646.800347222223
# ----> Epoch 995, Average loss -18876.6390625
# ----> Epoch 996, Average loss -2168.659722222222
# ----> Epoch 996, Average loss -4314.716145833333
# ----> Epoch 996, Average loss -6364.750347222222
# ----> Epoch 996, Average loss -8585.714409722223
# ----> Epoch 996, Average loss -10567.520833333334
# ----> Epoch 996, Average loss -12456.919444444444
# ----> Epoch 996, Average loss -14587.709895833334
# ----> Epoch 996, Average loss -16724.803993055557
# ----> Epoch 996, Average loss -18772.688541666666
# ----> Epoch 997, Average loss -2035.0928819444443
# ----> Epoch 997, Average loss -4095.6618055555555
# ----> Epoch 997, Average loss -6174.597222222223
# ----> Epoch 997, Average loss -8221.039583333333
# ----> Epoch 997, Average loss -10393.564930555556
# ----> Epoch 997, Average loss -12421.356076388889
# ----> Epoch 997, Average loss -14621.333854166667
# ----> Epoch 997, Average loss -16675.184895833332
# ----> Epoch 997, Average loss -18790.52951388889
# ----> Epoch 998, Average loss -2182.3581597222224
# ----> Epoch 998, Average loss -4213.431770833334
# ----> Epoch 998, Average loss -6233.578125
# ----> Epoch 998, Average loss -8285.713541666666
# ----> Epoch 998, Average loss -10417.15138888889
# ----> Epoch 998, Average loss -12500.975868055555
# ----> Epoch 998, Average loss -14713.315972222223
# ----> Epoch 998, Average loss -16602.075
# ----> Epoch 998, Average loss -18831.496875
# ----> Epoch 999, Average loss -2142.279861111111
# ----> Epoch 999, Average loss -4402.1826388888885
# ----> Epoch 999, Average loss -6488.817881944445
# ----> Epoch 999, Average loss -8493.022222222222
# ----> Epoch 999, Average loss -10612.22013888889
# ----> Epoch 999, Average loss -12780.077777777778
# ----> Epoch 999, Average loss -14773.99079861111
# ----> Epoch 999, Average loss -16724.74079861111
# ----> Epoch 999, Average loss -18817.601215277777
# ----> Epoch 1000, Average loss -1952.3010416666666
# ----> Epoch 1000, Average loss -4087.961111111111
# ----> Epoch 1000, Average loss -6122.562847222222
# ----> Epoch 1000, Average loss -8331.631770833334
# ----> Epoch 1000, Average loss -10319.218055555555
# ----> Epoch 1000, Average loss -12341.636284722223
# ----> Epoch 1000, Average loss -14514.93454861111
# ----> Epoch 1000, Average loss -16648.237847222223
# ----> Epoch 1000, Average loss -18745.67013888889
# ----> Epoch 1001, Average loss -2086.6253472222224
# ----> Epoch 1001, Average loss -4202.349479166666
# ----> Epoch 1001, Average loss -6481.605208333333
# ----> Epoch 1001, Average loss -8296.973263888889
# ----> Epoch 1001, Average loss -10449.175347222223
# ----> Epoch 1001, Average loss -12558.55329861111
# ----> Epoch 1001, Average loss -14596.742708333333
# ----> Epoch 1001, Average loss -16633.115972222222
# ----> Epoch 1001, Average loss -18762.67465277778
# ----> Epoch 1002, Average loss -2223.3753472222224
# ----> Epoch 1002, Average loss -4459.485763888889
# ----> Epoch 1002, Average loss -6571.036284722222
# ----> Epoch 1002, Average loss -8395.46736111111
# ----> Epoch 1002, Average loss -10379.238888888889
# ----> Epoch 1002, Average loss -12608.464409722223
# ----> Epoch 1002, Average loss -14630.494965277778
# ----> Epoch 1002, Average loss -16735.483506944445
# ----> Epoch 1002, Average loss -18819.390972222223
# ----> Epoch 1003, Average loss -1994.6961805555557
# ----> Epoch 1003, Average loss -3899.704166666667
# ----> Epoch 1003, Average loss -5885.395659722222
# ----> Epoch 1003, Average loss -7964.023611111111
# ----> Epoch 1003, Average loss -10095.488888888889
# ----> Epoch 1003, Average loss -12163.99375
# ----> Epoch 1003, Average loss -14498.2140625
# ----> Epoch 1003, Average loss -16535.11875
# ----> Epoch 1003, Average loss -18790.87517361111
# ----> Epoch 1004, Average loss -1898.5918402777777
# ----> Epoch 1004, Average loss -4118.601388888889
# ----> Epoch 1004, Average loss -6304.2578125
# ----> Epoch 1004, Average loss -8470.365625
# ----> Epoch 1004, Average loss -10414.475868055555
# ----> Epoch 1004, Average loss -12255.561284722222
# ----> Epoch 1004, Average loss -14575.219618055555
# ----> Epoch 1004, Average loss -16549.439930555556
# ----> Epoch 1004, Average loss -18725.264583333334
# ----> Epoch 1005, Average loss -2215.8578125
# ----> Epoch 1005, Average loss -4225.511631944444
# ----> Epoch 1005, Average loss -6310.652430555556
# ----> Epoch 1005, Average loss -8549.912152777777
# ----> Epoch 1005, Average loss -10583.959895833334
# ----> Epoch 1005, Average loss -12619.649305555555
# ----> Epoch 1005, Average loss -14833.631944444445
# ----> Epoch 1005, Average loss -16776.22517361111
# ----> Epoch 1005, Average loss -18864.766493055555
# ----> Epoch 1006, Average loss -2243.698263888889
# ----> Epoch 1006, Average loss -4392.860763888889
# ----> Epoch 1006, Average loss -6413.3609375
# ----> Epoch 1006, Average loss -8577.33298611111
# ----> Epoch 1006, Average loss -10536.922743055555
# ----> Epoch 1006, Average loss -12580.0640625
# ----> Epoch 1006, Average loss -14500.965277777777
# ----> Epoch 1006, Average loss -16634.72065972222
# ----> Epoch 1006, Average loss -18763.28715277778
# ----> Epoch 1007, Average loss -2025.9083333333333
# ----> Epoch 1007, Average loss -4141.644097222223
# ----> Epoch 1007, Average loss -6216.452951388889
# ----> Epoch 1007, Average loss -8426.716145833334
# ----> Epoch 1007, Average loss -10417.217708333334
# ----> Epoch 1007, Average loss -12485.676215277777
# ----> Epoch 1007, Average loss -14572.094444444445
# ----> Epoch 1007, Average loss -16593.12638888889
# ----> Epoch 1007, Average loss -18776.927430555555
# ----> Epoch 1008, Average loss -2114.4659722222223
# ----> Epoch 1008, Average loss -4135.750173611111
# ----> Epoch 1008, Average loss -6276.225868055555
# ----> Epoch 1008, Average loss -8439.468229166667
# ----> Epoch 1008, Average loss -10417.39982638889
# ----> Epoch 1008, Average loss -12688.30954861111
# ----> Epoch 1008, Average loss -14843.900868055556
# ----> Epoch 1008, Average loss -16748.06076388889
# ----> Epoch 1008, Average loss -18831.121875
# ----> Epoch 1009, Average loss -2170.4197916666667
# ----> Epoch 1009, Average loss -4298.2633680555555
# ----> Epoch 1009, Average loss -6390.2640625
# ----> Epoch 1009, Average loss -8478.737152777778
# ----> Epoch 1009, Average loss -10644.703645833333
# ----> Epoch 1009, Average loss -12767.486458333333
# ----> Epoch 1009, Average loss -15043.203472222222
# ----> Epoch 1009, Average loss -16835.437152777777
# ----> Epoch 1009, Average loss -18804.87777777778

# %%
#model.load_state_dict('/content/drive/MyDrive/MultiModalDeepLearning/audio_notebooks/autoenc.pth')
torch.save(model.state_dict(), '/content/drive/MyDrive/video_feat/autoenc_vidAud.pth')

# %%
### Testing latent space
testdat, labels = next(iter(testloader))
for i in range(0, 8):
  testdat_temp, labels_temp = next(iter(testloader))
  testdat = torch.cat([testdat,testdat_temp])
  labels = torch.cat([labels, labels_temp])


testdat = testdat.to(device)

testdat = torch.tensor(X,dtype=torch.float32)
y2 = le.transform(list(df.columns))
labels = torch.tensor(y2,dtype=torch.float32)

_, mu, logvar = model(testdat)
z = model.reparameterize(mu, logvar).data.cpu().numpy()


#z3 = np.append(z, labels)
#z3 = np.append(z, y2.reshape(-1), axis = 1)

# %%
np.save('/content/drive/MyDrive/video_feat/features/classes.npy', le.classes_)

# %%
df3 = pd.DataFrame(data = z, columns = ['x', 'y'])
df3['labels'] = y2
df3.head()
# Out:
#           x         y  labels
# 0  0.072882 -1.031886       0
# 1  0.118468  1.822440       1
# 2 -2.555076  0.105230       2
# 3 -1.036142 -0.167495       3
# 4 -3.358587 -1.058625       4

# %%
df3.to_csv('/content/drive/MyDrive/video_feat/features/audioVideo_z.csv', index=False)
torch.save(model.state_dict(), '/content/drive/MyDrive/video_feat/features/autoenc.pth')

# %%
import plotly.express as px

labals = labels.detach().to('cpu').numpy()
libels = []
for item in labals:
  item = str(item)
  libels.append(item)

fig = px.scatter(x=z[:, 0], y=z[:, 1], color=libels)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ac1d2028-e3ea-4c7a-83b7-1ab969c8dbb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac1d2028-e3ea-4c7a-83b7-1ab969c8dbb0")) {                    Plotly.newPlot(                        "ac1d2028-e3ea-4c7a-83b7-1ab969c8dbb0",                        [{"hovertemplate":"color=0.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"0.0","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"0.0","orientation":"v","showlegend":true,"x":[0.026167672127485275],"xaxis":"x","y":[-0.9830852746963501],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=1.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"1.0","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"1.0","orientation":"v","showlegend":true,"x":[0.15270403027534485],"xaxis":"x","y":[1.748406171798706],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=2.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"2.0","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"2.0","orientation":"v","showlegend":true,"x":[-2.6447629928588867],"xaxis":"x","y":[-0.001623561605811119],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=3.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"3.0","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"3.0","orientation":"v","showlegend":true,"x":[-0.7737249732017517],"xaxis":"x","y":[-0.12965694069862366],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=4.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"4.0","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"4.0","orientation":"v","showlegend":true,"x":[-3.652771472930908],"xaxis":"x","y":[-0.974044144153595],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=5.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"5.0","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"5.0","orientation":"v","showlegend":true,"x":[-1.4904719591140747],"xaxis":"x","y":[-0.8952948451042175],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=6.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"6.0","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"6.0","orientation":"v","showlegend":true,"x":[-0.41485095024108887],"xaxis":"x","y":[0.4363134503364563],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=7.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"7.0","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"7.0","orientation":"v","showlegend":true,"x":[-1.3157413005828857],"xaxis":"x","y":[2.9437601566314697],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=8.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"8.0","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"8.0","orientation":"v","showlegend":true,"x":[-2.153665781021118],"xaxis":"x","y":[-1.291891098022461],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=9.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"9.0","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"9.0","orientation":"v","showlegend":true,"x":[-0.03679221495985985],"xaxis":"x","y":[2.2114479541778564],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=10.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"10.0","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"10.0","orientation":"v","showlegend":true,"x":[0.2882939279079437],"xaxis":"x","y":[-2.6661391258239746],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=11.0<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"11.0","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"11.0","orientation":"v","showlegend":true,"x":[0.2909986674785614],"xaxis":"x","y":[-3.1008079 ...

# %%
from sklearn.cluster import KMeans

nclust = int(len(z) / 5)

kmeans = KMeans(n_clusters=nclust, random_state=0, n_init="auto").fit(z)
kmeans.labels_
# Out:
# array([13,  9, 11, 17,  4,  2, 11,  3,  5,  3,  2,  6,  9,  3,  5, 17,  9,
#        14, 14, 15, 12,  5,  5, 13,  6,  0,  5,  2, 15, 14,  5,  4,  8,  4,
#        17, 10,  0, 17,  0,  0, 15,  5,  5, 17,  0,  3,  7,  6,  8,  3,  2,
#         2, 15, 16, 12, 14,  5,  1,  8,  6,  7, 15, 14, 17, 14, 17,  7, 14,
#         5,  8,  4, 11,  4,  3,  5, 14,  8,  1,  6, 11,  9,  4,  5, 12,  2,
#         3,  2,  1,  1,  8], dtype=int32)

# %%
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=5)
neigh.fit(z)


nearest = neigh.kneighbors([[0,1]], return_distance=False).reshape(-1)
y3 = le.inverse_transform(y2)

most_similar = []
for k in nearest:
  most_similar.append(y3[k])

print(most_similar)
# Out:
# ['GAYLE-abcdefu', 'Bruno-Mars-That-s-What-I-Like', 'M-neskin-Beggin', 'Lil-Nas-X-Jack-Harlow-INDUSTRY-BABY', 'Kendrick-Lamar-HUMBLE']

# %%
def getNmax(array, N):
  idx = (-array[0]).argsort()[:N]
  return idx

def scaleProbs(max_prob):
  max_probs_scaled = ((max_prob - min(max_prob)) / (max(max_prob) - min(max_prob))).round(2)
  max_probs_scaled = ((max_prob - min(max_prob)) / (max_prob - min(max_prob)).sum()).round(2)

  return max_probs_scaled

def getNmaxClassesProbs(clf_classes, preds, N):
  max_classes = []
  max_probs = []

  nmax = getNmax(preds, N)

  for i in nmax:
    max_classes.append(clf_classes[i])
    max_probs.append(preds[0][i])

  max_probs_scaled = scaleProbs(max_probs)

  return max_classes, max_probs_scaled

clf = joblib.load('/content/drive/MyDrive/MultiModalDeepLearning/classifiers/audio_clf.joblib')

#pred = clf.predict_proba([X[0]])
pred = clf.predict_proba([X[0]])
max_cl, max_prob = getNmaxClassesProbs(clf.classes_, pred, 5)

print(max_prob)
print(max_cl)
# Out:
# [0.61 0.33 0.03 0.03 0.  ]
# ['Kendrick-Lamar-HUMBLE', 'ROSAL-A-DESPECH-', 'Doja-Cat-Woman', 'Billie-Eilish-bad-guy', 'Future-Mask-Off-Official-Music-Video-xvZqHgFz51I-']
